# %%
import sklearn
assert sklearn.__version__ >= "0.20"
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import feature_column
from tensorflow.keras.layers import Embedding, LSTM
from tensorflow.keras import layers
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import losses
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# %%
# Batch Size -- we set to 1 to just read it in
BATCH_SIZE = 1
DATASET_SIZE = 10000
train_size = 8000
test_size =2000

# %%
raw_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'text/',
    batch_size=32,
    subset='training',
    validation_split=0.2, 
    seed=49
)
# Out:
# Found 10000 files belonging to 2 classes.
# Using 8000 files for training.

# %%
raw_val_ds = tf.keras.preprocessing.text_dataset_from_directory(
   'text/',
    batch_size=32,
    validation_split=0.2, 
    subset='validation', 
    seed=49)
# Out:
# Found 10000 files belonging to 2 classes.
# Using 2000 files for validation.

# %%
print("Label 0 corresponds to", raw_train_ds.class_names[0])
print("Label 1 corresponds to", raw_train_ds.class_names[1])
# Out:
# Label 0 corresponds to clickbait
# Label 1 corresponds to normal

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    return lowercase

# %%
max_features = 10000
sequence_length = 20

vectorize_layer = TextVectorization(
#     standardize=custom_standardization,
    max_tokens=max_features,
    output_mode='int',
    output_sequence_length=sequence_length)

# %%
# Make a text-only dataset (without labels), then call adapt
train_text = raw_train_ds.map(lambda x, y: x)
vectorize_layer.adapt(train_text)

# %%
def vectorize_text(text, label):
  text = tf.expand_dims(text, -1)
  return vectorize_layer(text), label

# %%
train_ds = raw_train_ds.map(vectorize_text)
val_ds = raw_val_ds.map(vectorize_text)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
embedding_dim = 10

# %%
keras.backend.clear_session()
model = tf.keras.Sequential([
  layers.Embedding(max_features + 1, embedding_dim),
  LSTM(32, return_sequences=True),
  layers.GlobalAveragePooling1D(),
  layers.Dense(units=32, activation='relu'),
  layers.BatchNormalization(),
  layers.Dense(1,activation='sigmoid')])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 10)          100010
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 32)          5504
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                1056
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 106,731
# Trainable params: 106,667
# Non-trainable params: 64
# _________________________________________________________________

# %%
#[tf.metrics.BinaryAccuracy(threshold=0.5]
optimizer = keras.optimizers.Adam(lr=0.0001)
model.compile(loss=losses.BinaryCrossentropy(from_logits=True),
              optimizer='adam',
              metrics=['accuracy'])

# %%
epochs = 100
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 4s 8ms/step - loss: 0.6198 - accuracy: 0.7155 - val_loss: 0.5511 - val_accuracy: 0.7600
# Epoch 2/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.4967 - accuracy: 0.7704 - val_loss: 0.6737 - val_accuracy: 0.7600
# Epoch 3/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.2912 - accuracy: 0.8753 - val_loss: 1.9601 - val_accuracy: 0.7590
# Epoch 4/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.1512 - accuracy: 0.9439 - val_loss: 1.6132 - val_accuracy: 0.5910
# Epoch 5/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0889 - accuracy: 0.9715 - val_loss: 4.8061 - val_accuracy: 0.7600
# Epoch 6/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0684 - accuracy: 0.9776 - val_loss: 3.0863 - val_accuracy: 0.4100
# Epoch 7/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0655 - accuracy: 0.9805 - val_loss: 7.7938 - val_accuracy: 0.2720
# Epoch 8/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0569 - accuracy: 0.9821 - val_loss: 3.0537 - val_accuracy: 0.4550
# Epoch 9/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.0530 - accuracy: 0.9814 - val_loss: 7.6321 - val_accuracy: 0.7600
# Epoch 10/100
# 250/250 [==============================] - 2s 8ms/step - loss: 0.0378 - accuracy: 0.9865 - val_loss: 3.0363 - val_accuracy: 0.7175
# Epoch 11/100
# 107/250 [===========>..................] - ETA: 1s - loss: 0.0352 - accuracy: 0.9874
# ------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-208-8157ec5ac1ee> in <module>
#       3     train_ds,
#       4     validation_data=val_ds,
# ----> 5     epochs=epochs)
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
examples = [
  "The movie was great!",
  "The movie was okay.",
  "The movie was terrible..."
]

model.predict(examples)
# Out:
# ------------------------------------
# UnimplementedErrorTraceback (most recent call last)
# <ipython-input-202-9b4beb687ef0> in <module>
#       5 ]
#       6
# ----> 7 model.predict(examples)
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     893       # If we did not create any variables the trace we have is good enough.
#     894       return self._concrete_stateful_fn._call_flat(
# --> 895           filtered_flat_args, self._concrete_stateful_fn.captured_inputs)  # pylint: disable=protected-access
#     896
#     897     def fn_with_cond(inner_args, inner_kwds, inner_filtered_flat_args):
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# UnimplementedError:  Cast string to float is not supported
# 	 [[node sequential/Cast (defined at <ipython-input-202-9b4beb687ef0>:7) ]] [Op:__inference_predict_function_614409]
#
# Function call stack:
# predict_function

# %%
encoder = tf.keras.layers.experimental.preprocessing.TextVectorization(
    max_tokens=100000)
encoder.adapt(raw_train_ds.map(lambda text, label: text))

# %%
model = tf.keras.Sequential([
    encoder,
    tf.keras.layers.Embedding(
        input_dim=len(encoder.get_vocabulary()),
        output_dim=64,
        # Use masking to handle the variable sequence lengths
        mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])

# %%
history = model.fit(raw_train_ds, epochs=10,
                    validation_data=raw_val_ds, 
                    validation_steps=30)
# Out:
# Epoch 1/10
# 250/250 [==============================] - 34s 66ms/step - loss: 0.6517 - accuracy: 0.3514 - val_loss: 0.5736 - val_accuracy: 0.7260
# Epoch 2/10
# 250/250 [==============================] - 9s 37ms/step - loss: 0.5694 - accuracy: 0.7309 - val_loss: 0.5736 - val_accuracy: 0.7292
# Epoch 3/10
# 250/250 [==============================] - 8s 33ms/step - loss: 0.5498 - accuracy: 0.7364 - val_loss: 0.5760 - val_accuracy: 0.7229
# Epoch 4/10
# 250/250 [==============================] - 9s 34ms/step - loss: 0.4816 - accuracy: 0.7808 - val_loss: 0.7079 - val_accuracy: 0.6135
# Epoch 5/10
# 250/250 [==============================] - 9s 35ms/step - loss: 0.3122 - accuracy: 0.8666 - val_loss: 1.0152 - val_accuracy: 0.5406
# Epoch 6/10
# 250/250 [==============================] - 8s 33ms/step - loss: 0.1954 - accuracy: 0.9180 - val_loss: 1.3324 - val_accuracy: 0.5948
# Epoch 7/10
# 250/250 [==============================] - 8s 34ms/step - loss: 0.1212 - accuracy: 0.9547 - val_loss: 1.6185 - val_accuracy: 0.6083
# Epoch 8/10
# 233/250 [==========================>...] - ETA: 0s - loss: 0.0837 - accuracy: 0.9722
# ------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-85-21b992da75de> in <module>
#       1 history = model.fit(raw_train_ds, epochs=10,
#       2                     validation_data=raw_val_ds,
# ----> 3                     validation_steps=30)
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /opt/miniconda3/envs/python/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
for text_batch, label_batch in full_ds.take(1):
    for i in range(3):
        print("Review", text_batch.numpy()[i])
        print("Label", label_batch.numpy()[i])
# Out:
# Review b'California university dispenses morning-after pill in vending machine\nFrance to suspend sales of a Vitamin D supplement after the death of a 10-day-old baby\nWhy Trump\xe2\x80\x99s decision to launch missiles into Syria is at odds with nearly everything he has said about Syria\nFamous lifetime warranty in question\nDive instructor rescues shark with knife wedged in its head\n18 million people would lose insurance in 2018 if Obamacare is partially repealed, a congressional study says\nCongratulations @Gurmeet @Debina!\nYou guys are inspiring!\nWal-Mart is under pressure to fix its rampant crime problem\nMoney managers all agree one trade is really crowded, but they\'re loading up on it anyway\nThat "10 concerts" Facebook meme? It could be used by marketers to target ads or by hackers to breach accounts.\nAvenged Sevenfold vs. Warner Bros.: Inside the potentially history-making legal showdown\nWhat goes on in your brain when you get d\xc3\xa9j\xc3\xa0 vu\nPres. Trump plays full 18 holes of golf with professional golfer Rory McIlroy in Florida:\nThe tech industry largely opposed Donald Trump during the campaign. Next week, he\'ll meet with Silicon Valley CEOs.\nQuote of the day:\nMore than 1,000 law school professors have rejected Donald Trump\'s choice for Attorney General\nTerps turn to March Madness after maddening loss to Northwestern in Big Ten tournament\nNetflix has added a revolutionary new button\nFlying in and out of #Delhi may get much cheaper by coming summer break\nListen to @LupeFiasco\'s new track "Killers":\nWill \'masala\' bonds spice up the Indian economy?\nStar Wars\' creator George Lucas to site new museum in Los Angeles\nMilitary aircraft that appeared low over Manhattan were conducting "routine training"\nCreepy shipment of snakes, spiders and scorpions is not the kind of mail you want to open\nTrump\xe2\x80\x99s first month of travel expenses is on track to surpass Barack Obama\xe2\x80\x99s average year:\nPolice release images of three suspects after brutal attack on teen refugee\nPresident-elect Trump is out of step with both science and public opinion on climate change\nThe new \xc2\xa31 coin is here, and it has caused a few problems along the way\nCheltenham Festival: Douvan can make it 14 wins in a row for Mullins  via @guardian_sport\n"This Is Us" writers to take second stab at "HIMYM" spinoff\nOh goodie.\nTop #entertainment stories from the day  that was\nUPDATE: One dead after Mt Warning campers struck by lightning, rescue operation underway\nWhite House adviser Kellyanne Conway \'repeatedly punched man\' at inauguration ball\nHong Kong\'s new leader will inherit the world\'s freest economy, but also a fragile one\nSecurity surrounding the inauguration of Donald Trump is proving to be the most challenging in recent history\nLondon Underground fined \xc2\xa3500,000 after maintenance worker injured in a fall\n"Just because your kids are headed off to college, it doesn\xe2\x80\x99t mean they\xe2\x80\x99ll graduate"\n22 gifts your dude will actually want for valentine\xe2\x80\x99s day\nWitness the remarkable zen of Russell Crowe\'s smartphone photography\nU.S. Army charges retired general with raping a minor in 1980s\nThe Turkish policeman who murdered the Russian ambassador to Ankara used his police ID to bypass metal detectors\nAn Aussie fund giant bets on U.S. banks and infrastructure firms thanks to Trump\nThese are the weirdest things you\'ll find in Russia\'s \'patriotic theme park\'\nRussia must be held accountable for Ukraine, says Mike Pence\nDystopian fiction is selling like there\'s no tomorrow\nMcDonald\'s can\'t keep up with its all-day-breakfast launch\n#ICYMI: #Senate recount after High Court rules #Culleton\'s election #invalid\nInside Obama and Netanyahu\'s strained relationship:\n.@FakeShark brings new single "Heart 2 Heart" to life in colorful video: (premiere)\nBolton on Trump\'s Taiwan Call: China Doesn\'t Tell Us Who We Can Talk To\nNigel Farage to host new nightly LBC rad ...
# Label 0
# ------------------------------------
# IndexErrorTraceback (most recent call last)
# <ipython-input-33-a6bc47fde434> in <module>
#       1 for text_batch, label_batch in full_ds.take(1):
#       2     for i in range(3):
# ----> 3         print("Review", text_batch.numpy()[i])
#       4         print("Label", label_batch.numpy()[i])
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
# Convert csv to dataset
def csv_to_dataset(csv,batch_size=1,shuffle=False):
    ds = tf.data.experimental.make_csv_dataset(
        csv,
        batch_size=batch_size, # Artificially small to make examples easier to show.
        label_name='isClickbait',
        num_epochs=1,
        shuffle=False,
        #column_defaults=['float64','float64','float64','int64','float64','float64','float64','float64','int64','float64','float64','float64','float64','float64'],
        ignore_errors=True,)
    return ds

# %%
# get full dataset
full_ds = csv_to_dataset('tweets.csv',batch_size=BATCH_SIZE)
# #shuffle
tf.random.set_seed(49)
full_ds = full_ds.shuffle(buffer_size=10000,reshuffle_each_iteration=False)
# get train val ds
train_val_ds = full_ds.take(train_size)
# get test ds
test_ds = full_ds.skip(train_size)

# # get train / valid ds
train_ds = train_val_ds.take(int(train_size*.75))
valid_ds = train_val_ds.skip(int(train_size*.75))

# %%
# Batch into 32
train_val_ds=train_ds.batch(32)
train_ds=train_ds.batch(32)
valid_ds=valid_ds.batch(32)
test_ds=test_ds.batch(32)

# %%
# column labels
labels= ['postMedia', 'postText', 'id', 'targetCaptions', 'targetParagraphs',
       'targetTitle', 'postTimestamp', 'targetKeywords', 'targetDescription',
       'isClickbait']
categorical = ['CHAS','RAD']
numeric = ['CRIM','ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',]
features = ['postText', 'id', 'targetCaptions', 'targetParagraphs',
       'targetTitle', 'postTimestamp', 'targetKeywords', 'targetDescription',]
